# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/Analyzing the Impact of Car Features on Price and Profitability (1).xlsx')
df.head(1)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011        335                 6            MANUAL
#
#       Driven_Wheels             Engine Fuel Type  Number of Doors  \
# 0  rear wheel drive  premium unleaded (required)              2.0
#
#                       Market Category Vehicle Size Vehicle Style  highway MPG  \
# 0  Factory Tuner,Luxury,High-Performa      Compact         Coupe           26
#
#    city mpg  Popularity   MSRP
# 0        19        3916  46135

# %%
df['Number of Doors'] = df['Number of Doors'].astype('int64', errors='ignore')
df['Number of Doors'].head()
# Out:
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: Number of Doors, dtype: float64

# %%
df['Number of Doors'] = df['Number of Doors'].astype('int32', errors='ignore')
df['Number of Doors'].head()
# Out:
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: Number of Doors, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11199 entries, 0 to 11198
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11199 non-null  object
#  1   Model              11199 non-null  object
#  2   Year               11199 non-null  int64
#  3   Engine HP          11199 non-null  int64
#  4   Engine Cylinders   11199 non-null  int64
#  5   Transmission Type  11199 non-null  object
#  6   Driven_Wheels      11199 non-null  object
#  7   Engine Fuel Type   11199 non-null  object
#  8   Number of Doors    11193 non-null  float64
#  9   Market Category    7823 non-null   object
#  10  Vehicle Size       11199 non-null  object
#  11  Vehicle Style      11199 non-null  object
#  12  highway MPG        11199 non-null  int64
#  13  city mpg           11199 non-null  int64
#  14  Popularity         11199 non-null  int64
#  15  MSRP               11199 non-null  int64
# dtypes: float64(1), int64(7), object(8)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011        335                 6            MANUAL
# 1  BMW    1 Series  2011        300                 6            MANUAL
# 2  BMW    1 Series  2011        300                 6            MANUAL
# 3  BMW    1 Series  2011        230                 6            MANUAL
# 4  BMW    1 Series  2011        230                 6            MANUAL
#
#       Driven_Wheels             Engine Fuel Type  Number of Doors  \
# 0  rear wheel drive  premium unleaded (required)              2.0
# 1  rear wheel drive  premium unleaded (required)              2.0
# 2  rear wheel drive  premium unleaded (required)              2.0
# 3  rear wheel drive  premium unleaded (required)              2.0
# 4  rear wheel drive  premium unleaded (required)              2.0
#
#                       Market Category Vehicle Size Vehicle Style  highway MPG  \
# 0  Factory Tuner,Luxury,High-Performa      Compact         Coupe           26
# 1                  Luxury,Performance      Compact   Convertible           28
# 2             Luxury,High-Performance      Compact         Coupe           28
# 3                  Luxury,Performance      Compact         Coupe           28
# 4                              Luxury      Compact   Convertible           28
#
#    city mpg  Popularity   MSRP
# 0        19        3916  46135
# 1        19        3916  40650
# 2        20        3916  36350
# 3        18        3916  29450
# 4        18        3916  34500

# %%
df['Market Category'] = df['Market Category'].str.split(',').str[0]

# %%
df.head()
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011        335                 6            MANUAL
# 1  BMW    1 Series  2011        300                 6            MANUAL
# 2  BMW    1 Series  2011        300                 6            MANUAL
# 3  BMW    1 Series  2011        230                 6            MANUAL
# 4  BMW    1 Series  2011        230                 6            MANUAL
#
#       Driven_Wheels             Engine Fuel Type  Number of Doors  \
# 0  rear wheel drive  premium unleaded (required)              2.0
# 1  rear wheel drive  premium unleaded (required)              2.0
# 2  rear wheel drive  premium unleaded (required)              2.0
# 3  rear wheel drive  premium unleaded (required)              2.0
# 4  rear wheel drive  premium unleaded (required)              2.0
#
#   Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 0   Factory Tuner      Compact         Coupe           26        19
# 1          Luxury      Compact   Convertible           28        19
# 2          Luxury      Compact         Coupe           28        20
# 3          Luxury      Compact         Coupe           28        18
# 4          Luxury      Compact   Convertible           28        18
#
#    Popularity   MSRP
# 0        3916  46135
# 1        3916  40650
# 2        3916  36350
# 3        3916  29450
# 4        3916  34500

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine HP               0
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Engine Fuel Type        0
# Number of Doors         6
# Market Category      3376
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Engine Fuel Type     0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df['Market Category'] = df['Market Category'].fillna(df['Market Category'].mode()[0])

# %%
df['Number of Doors'] = df['Number of Doors'].fillna(df['Number of Doors'].mode()[0])

# %%
df.drop_duplicates(inplace=True)

# %%
df['Popularity']
# Out:
# 0        3916
# 1        3916
# 2        3916
# 3        3916
# 4        3916
#          ...
# 11194     204
# 11195     204
# 11196     204
# 11197     204
# 11198      61
# Name: Popularity, Length: 11199, dtype: int64

# %%
result = df.groupby(['Model', 'Market Category'])['Popularity'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      58     try:
# ---> 59         return bound(*args, **kwds)
#      60     except TypeError:
#
# TypeError: '<' not supported between instances of 'int' and 'datetime.datetime'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-0ca43401d265> in <cell line: 1>()
# ----> 1 result = df.groupby(['Model', 'Market Category'])['Popularity'].sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2261             # _agg_general() returns. GH #31422
#    2262             with com.temp_setattr(self, "observed", True):
# -> 2263                 result = self._agg_general(
#    2264                     numeric_only=numeric_only,
#    2265                     min_count=min_count,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1420         npfunc: Callable,
#    1421     ):
# -> 1422         result = self._cython_agg_general(
#    1423             how=alias,
#    1424             alt=npfunc,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1505             return result
#    1506
# -> 1507         new_mgr = data.grouped_reduce(array_func)
#    1508         res = self._wrap_agged_manager(new_mgr)
#    1509         out = self._wrap_aggregated_output(res)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in grouped_reduce(self, func)
#     195     def grouped_reduce(self, func):
#     196         arr = self.array
# --> 197         res = func(arr)
#     198         index = default_index(len(res))
#     199
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1488         def array_func(values: ArrayLike) -> ArrayLike:
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#    1492                     values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     953         assert kind in ["transform", "aggregate"]
#     954
# --> 955         cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
#     956
#     957         ids, _, _ = self.group_info
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in has_dropped_na(self)
#     867         Whether grouper has null value(s) that are dropped.
#     868         """
# --> 869         return bool((self.group_info[0] < 0).any())
#     870
#     871     @cache_readonly
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in group_info(self)
#     871     @cache_readonly
#     872     def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 873         comp_ids, obs_group_ids = self._get_compressed_codes()
#     874
#     875         ngroups = len(obs_group_ids)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_compressed_codes(self)
#     890         # The first returned ndarray may have any signed integer dtype
#     891         if len(self.groupings) > 1:
# --> 892             group_index = get_group_index(self.codes, self.shape, sort=True, xnull=True)
#     893             return compress_group_index(group_index, sort=self._sort)
#     894             # FIXME: compress_group_index's second return value is int64, not intp
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in codes(self)
#     822     @property
#     823     def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 824         return [ping.codes for ping in self.groupings]
#     825
#     826     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in <listcomp>(.0)
#     822     @property
#     823     def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 824         return [ping.codes for ping in self.groupings]
#     825
#     826     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in codes(self)
#     669     @property
#     670     def codes(self) -> npt.NDArray[np.signedinteger]:
# --> 671         return self._codes_and_uniques[0]
#     672
#     673     @cache_readonly
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in _codes_and_uniques(self)
#     778             # error: Incompatible types in assignment (expression has type "Union[
#     779             # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 780             codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     781                 self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     782             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize(values, sort, use_na_sentinel, size_hint)
#     785
#     786     if sort and len(uniques) > 0:
# --> 787         uniques, codes = safe_sort(
#     788             uniques,
#     789             codes,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in safe_sort(values, codes, use_na_sentinel, assume_unique, verify)
#    1538         and lib.infer_dtype(values, skipna=False) == "mixed-integer"
#    1539     ):
# -> 1540         ordered = _sort_mixed(values)
#    1541     else:
#    1542         try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in _sort_mixed(values)
#    1606     num_pos = ~str_pos & ~null_pos
#    1607     str_argsort = np.argsort(values[str_pos])
# -> 1608     num_argsort = np.argsort(values[num_pos])
#    1609     # convert boolean arrays to positional indices, then order by underlying values
#    1610     str_locs = str_pos.nonzero()[0].take(str_argsort)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in argsort(a, axis, kind, order)
#    1131
#    1132     """
# -> 1133     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#    1134
#    1135
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      66         # Call _wrapit from within the except clause to ensure a potential
#      67         # exception has a traceback chain.
# ---> 68         return _wrapit(obj, method, *args, **kwds)
#      69
#      70
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      43     except AttributeError:
#      44         wrap = None
# ---> 45     result = getattr(asarray(obj), method)(*args, **kwds)
#      46     if wrap:
#      47         if not isinstance(result, mu.ndarray):
#
# TypeError: '<' not supported between instances of 'int' and 'datetime.datetime'

# %%
'Model', 'Market Category

# %% [markdown]
# **●	Task 1.A: Create a pivot table that shows the number of car models in each market category and their corresponding popularity scores.**

# %%
df['Model']= df['Model'].astype('str')

# %%
df.groupby(['Model','Market Category'])['Popularity'].mean()
# Out:
# Model       Market Category
# 1 Series    Luxury             3916.0
# 1 Series M  Factory Tuner      3916.0
# 100         Luxury             3105.0
# 124 Spider  Performance         819.0
# 190-Class   Luxury              617.0
#                                 ...
# iQ          Hatchback           105.0
# tC          Hatchback           105.0
# xA          Hatchback           105.0
# xB          Crossover           105.0
# xD          Hatchback           105.0
# Name: Popularity, Length: 1129, dtype: float64

# %% [markdown]
# **●	Task 2:  Create a scatter chart that plots engine power on the x-axis and price on the y-axis. Add a trendline to the chart to visualize the relationship between these variables.**

# %%
df.plot.scatter(x ='Engine HP',y='MSRP')
# Out:
# <Axes: xlabel='Engine HP', ylabel='MSRP'>

# %% [markdown]
#  **●	Task 3: Use regression analysis to identify the variables that have the strongest relationship with a car's price. Then create a bar chart that shows the coefficient values for each variable to visualize their relative importance.**

# %%
df.head()
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011        335                 6            MANUAL
# 1  BMW    1 Series  2011        300                 6            MANUAL
# 2  BMW    1 Series  2011        300                 6            MANUAL
# 3  BMW    1 Series  2011        230                 6            MANUAL
# 4  BMW    1 Series  2011        230                 6            MANUAL
#
#       Driven_Wheels             Engine Fuel Type  Number of Doors  \
# 0  rear wheel drive  premium unleaded (required)              2.0
# 1  rear wheel drive  premium unleaded (required)              2.0
# 2  rear wheel drive  premium unleaded (required)              2.0
# 3  rear wheel drive  premium unleaded (required)              2.0
# 4  rear wheel drive  premium unleaded (required)              2.0
#
#   Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 0   Factory Tuner      Compact         Coupe           26        19
# 1          Luxury      Compact   Convertible           28        19
# 2          Luxury      Compact         Coupe           28        20
# 3          Luxury      Compact         Coupe           28        18
# 4          Luxury      Compact   Convertible           28        18
#
#    Popularity   MSRP
# 0        3916  46135
# 1        3916  40650
# 2        3916  36350
# 3        3916  29450
# 4        3916  34500

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(df[['Engine HP', 'Engine Cylinders', 'Number of Doors', 'highway MPG', 'city mpg', 'Popularity']], df['MSRP'])
# Out:
# LinearRegression()

# %%
pd.Series(model.coef_,index=['Engine HP', 'Engine Cylinders', 'Number of Doors', 'highway MPG', 'city mpg', 'Popularity'])
# Out:
# Engine HP            306.193257
# Engine Cylinders    7124.050701
# Number of Doors    -4755.684176
# highway MPG          555.987328
# city mpg             585.662263
# Popularity            -3.453231
# dtype: float64

# %%
a = model.coef_

# %%
b = ['Engine HP', 'Engine Cylinders', 'Number of Doors', 'highway MPG', 'city mpg', 'Popularity']

# %%
sns.barplot(x=a,y=b)
# Out:
# <Axes: >

# %% [markdown]
# **Task 4Insight Required: How does the average price of a car vary across different manufacturers?
# ●	Task 4.A: Create a pivot table that shows the average price of cars for each manufacturer.
# ●	Task 4.B: Create a bar chart or a horizontal stacked bar chart that visualizes the relationship between manufacturer and average price.**

# %%
df.groupby('Make').MSRP.mean()
# Out:
# Make
# Acura            3.508749e+04
# Alfa Romeo       6.160000e+04
# Aston Martin     1.981235e+05
# Audi             5.457412e+04
# BMW              6.216256e+04
# Bentley          2.471693e+05
# Bugatti          1.757224e+06
# Buick            2.903419e+04
# Cadillac         5.636827e+04
# Chevrolet        2.907473e+04
# Chrysler         2.672296e+04
# Dodge            2.485705e+04
# FIAT             2.267024e+04
# Ferrari          2.382188e+05
# Ford             2.851131e+04
# GMC              3.244409e+04
# Genesis          4.661667e+04
# HUMMER           3.646441e+04
# Honda            2.665515e+04
# Hyundai          2.492626e+04
# Infiniti         4.264027e+04
# Kia              2.551376e+04
# Lamborghini      3.315673e+05
# Land Rover       6.806709e+04
# Lexus            4.754907e+04
# Lincoln          4.386082e+04
# Lotus            6.837714e+04
# Maserati         1.136845e+05
# Maybach          5.462219e+05
# Mazda            2.041662e+04
# McLaren          2.398050e+05
# Mercedes-Benz    7.206953e+04
# Mitsubishi       2.134056e+04
# Nissan           2.892115e+04
# Oldsmobile       1.284380e+04
# Plymouth         3.296873e+03
# Pontiac          1.980004e+04
# Porsche          1.016224e+05
# Rolls-Royce      3.511306e+05
# Saab             2.787981e+04
# Scion            1.993250e+04
# Spyker           2.149900e+05
# Subaru           2.424067e+04
# Suzuki           1.802642e+04
# Tesla            8.525556e+04
# Toyota           2.884656e+04
# Volkswagen       2.897852e+04
# Volvo            2.972468e+04
# Name: MSRP, dtype: float64

# %% [markdown]
# **Insight Required: What is the relationship between fuel efficiency and the number of cylinders in a car's engine?
# ●	Task 5.A: Create a scatter plot with the number of cylinders on the x-axis and highway MPG on the y-axis. Then create a trendline on the scatter plot to visually estimate the slope of the relationship and assess its significance.
# ●	Task 5.B: Calculate the correlation coefficient between the number of cylinders and highway MPG to quantify the strength and direction of the relationship.**

# %%
a = df[['highway MPG','Engine Cylinders']]

# %%
sns.regplot(x='Engine Cylinders',y='highway MPG',data=a)
# Out:
# <Axes: xlabel='Engine Cylinders', ylabel='highway MPG'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11197 entries, 0 to 11198
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11197 non-null  object
#  1   Model              11197 non-null  object
#  2   Year               11197 non-null  int64
#  3   Engine HP          11197 non-null  int64
#  4   Engine Cylinders   11197 non-null  int64
#  5   Transmission Type  11197 non-null  object
#  6   Driven_Wheels      11197 non-null  object
#  7   Engine Fuel Type   11197 non-null  object
#  8   Number of Doors    11197 non-null  float64
#  9   Market Category    11197 non-null  object
#  10  Vehicle Size       11197 non-null  object
#  11  Vehicle Style      11197 non-null  object
#  12  highway MPG        11197 non-null  int64
#  13  city mpg           11197 non-null  int64
#  14  Popularity         11197 non-null  int64
#  15  MSRP               11197 non-null  int64
# dtypes: float64(1), int64(7), object(8)
# memory usage: 1.5+ MB
